# %%
import pandas as pd

# %%
df = pd.read_csv(r'results\redcliff_healthcenter\results.csv',index_col=0)

#df = df.sort_index()
df = df.sort_values('skMean',ascending=False)
df['skMean'] = df.skMean.round(3)
df['skPos'] = df.skPos.round(3)

df
# Out:
#    u1  u2  d   n   f  skMean  skPos   e
# 0  48  24  0  24   2  -0.736  0.338  25
# 1  96  12  0  24  13  -0.776  0.346  35
